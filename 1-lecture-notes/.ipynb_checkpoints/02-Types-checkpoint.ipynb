# %% [markdown]
# # 2. Types

# %% [markdown]
# There are three different kinds of numerical objects in Python - a more formal definition of objects later in the course. Most of the examples above deal with integer numbers. To check the type of a quantity in python you can use the built-in type() function. For example, we have **integters**:

# %%
type(1)
# Out:
# int

# %% [markdown]
# Not all real numbers can be represented on a computer, due to the fact that a fixed amound of memory is used to store each number (i.e. we can only save a fixed number of digits). Floating point notation is the common way to store numbers in a computer program, for this reason Python calls its representation of real numbers **float**.

# %%
type(3.1)
# Out:
# float

# %%
type(3e3)
# Out:
# float

# %% [markdown]
# (Side note. Floating point notation is closely related to the scientific notation we are familiar with, where we use a significand and an exponent to represent a real number. For example in base 10, 1234.56 = 123456 × 10$^{-2}$. So in a computer this would be stored as 123456 along with -2. The name "floating" refers to the fact that the decimal point could float to any position by changing the exponent without changing the integer significand.)

# %% [markdown]
# The last numerical type that we can use in python corresponds to **complex numbers**. The imaginary unit is written with the engineering notation, using the letter j. Note that we don't have to specify the multiplication between the imaginary part of the complex number and the imaginary unit.

# %%
type(3+1j)
# Out:
# complex

# %% [markdown]
# We can also check that things inside quotations are **strings** in Python

# %%
type("hello")
# Out:
# str

# %% [markdown]
# Coming back to the Check_a variable earlier, we can see that it's a **Boolean** type, meaning it can take either True or False.

# %%
Check_a = True
type(Check_a)
# Out:
# bool

# %% [markdown]
# Python allows to perform logical operations with boolean objects, in particular the logical __and__, __or__, and __not__ operations can be used on boolean variables. Refresher on Truth Tables

# %%
Check_a=True
Check_b=False

# %%
print(Check_a and Check_b, Check_a or Check_b, not Check_a)
# Out:
# False True False

# %% [markdown]
# ## Exercise: Getting User Input
#
# We can prompt the user of a python program to provide some input values using the input() function.

# %%
user_input=input("Please enter a number: ")
# Out:
# Please enter a number: 5

# %% [markdown]
# The result of the input() function is the text written by the user. In the example above is the character "5", which is labelled as user_input.

# %%
user_input
# Out:
# '5'

# %% [markdown]
# If we want to use this number to perform some math operations, we will run into a problem:

# %%
user_input + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xh/n6q6l6890l3g5t5p_d5xt_f40000gn/T/ipykernel_1176/3733534021.py in <module>
# ----> 1 user_input + 1
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Why is that? Turns out that "user_input" is taken as a string. We need to convert it to an actual integer before operating on it.

# %%
integer_user_input=int(user_input)
print(integer_user_input)
# Out:
# 5

# %%
type(integer_user_input)
# Out:
# int

# %% [markdown]
# ## Type casting
# More generally, to convert numbers from one type to another, we can use the name of these types as functions. e.g. int() will try to convert its argument into an integer.

# %%
int(3.0)
# Out:
# 3

# %% [markdown]
# Does int() perform rounding? Ceiling? Floor?

# %%
a=int(3.6)
print(a)
type(a)
# Out:
# 3
# int

# %% [markdown]
# Same with int to float conversion. And int to complex conversion

# %%
a=float(3)
print(a)
type(a)
# Out:
# 3.0
# float

# %%
ci=complex(3)
print(ci)
type(ci)
# Out:
# (3+0j)
# complex

# %% [markdown]
# The following will be problematic because there's no well-defined way of doing it.

# %%
int(3+4j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xh/n6q6l6890l3g5t5p_d5xt_f40000gn/T/ipykernel_1176/4193997112.py in <module>
# ----> 1 int(3+4j)
#
# TypeError: can't convert complex to int

# %% [markdown]
# The right way of taking the real and imaginary parts of a complex number is

# %%
print((3+4j).real)
print((3+4j).imag)
# Out:
# 3.0
# 4.0

# %% [markdown]
# ## Exercise: Convert photon energy to wavelength, continued

# %% [markdown]
# Based on our earlier photon energy to wavelength conversion code, modify it so that it takes in a user input as the energy, and detects whether it's red (i.e. between 620 and 750nm). We will talk about conditionals (if statements) more later in the next lectures.

# %%
# defining variable useful for the calculation
h = 6.626e-34
c = 3e8
energy = input("Please input a photon energy in eV: ")
energy = float(energy)
eV2J = 1.6e-19  
m2nm = 1e-9

# convert photon energy in eV into wavelength in nm
L = h * c / (energy * eV2J) / m2nm
print("The wavelength of a photon with energy ", energy, "eV is ",L, " nm")

if 620<L<750:
    print("The photon is red")
# Out:
# Please input a photon energy in eV: 2.0
# The wavelength of a photon with energy  2.0 eV is  621.1875  nm
# The photon is red
