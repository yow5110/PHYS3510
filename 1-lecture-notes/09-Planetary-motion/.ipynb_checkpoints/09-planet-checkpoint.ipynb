# %% [markdown]
# # 9. Project: Planetary motion
#
# In this project you will implement a code to simulate planetary motion. You will use the Runge-Kutta
# 2nd order method to integrate the equations of motion.
#
# The project is organized into six tasks, through which you'll develop a single program.

# %% [markdown]
# ## Task 1
#
# First a quick analytical calculation to set up initial conditions for our problem. You'll just need
# pen and paper and a calculator for this, and show your work in comments.
#
# We assume that the Sun is fixed at the origin (0,0) and that we know the perihelion and aphelion
# (Earth's nearest and farthest point from the Sun respectively) to be 147.1 million km and 152.1 million km.
#
# Make an analytical calculation of what the Earth's velocities are at these two points, $v_1$ and $v_2$.
# An exaggerated figure showing the elliptical orbit is shown below. The actual orbit is almost circular.
# You can solve it with two simple equations! **Write down your steps in calculating $v_1$ and $v_2$ in the
# code as a comment, otherwise no points will be given.** You'll get to use $v_1$ in Task 3.
#
# **Hint 1, Conservation of energy:** Write down the total energy = kinetic energy plus gravitational
# potential energy ($-\frac{GMm}{r}$) at the two points and equate them.
#
# **Hint 2, Conservation of angular momentum, a.k.a. Kepler's Second Law:** A line segment joining Earth
# and Sun sweeps out equal areas during equal intervals of time. Take a tiny sweep across an infinitesimally
# small time $\Delta t$ near the perihelion and aphelion, and equate the areas (blue areas in figure). $\Delta t$
# will cancel out in the end. You can look up the Solar mass and Gravitational Constant you need on Google.
#
# *(See the orbit diagram below)*

# %% [markdown]
# ![image.png](attachment:e5a16e79-a31f-40d3-ae5c-c2f192a1b0b0.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

G = 
Msun = 
R1 = 147.1e9  # perihelion
R2 = 152.1e9  # aphelion

# Calculate zvel1 analytically and write down your steps 
zvel1 =

# %% [markdown]
# ## Task 2
#
# What's the characteristic timescale $\tau$ if you want to simulate the trajectory of Earth around the
# Sun? Describe how you use $\tau$ to determine an appropriate timestep `dt` for this simulation.

# %% [markdown]
# ## Task 3
#
# Initialize the Earth at the Perihelion with velocity $v_1$ pointing in the appropriate direction. It's
# easiest to set up everything in SI units. Implement the expression for the gravitational force acting on
# the Earth
#
# $$\vec{F} = -\frac{GMm}{r^2}\hat{r} = -\frac{GMm}{r^3}\vec{r}$$
#
# and the corresponding acceleration in the function `diffeq()`. Here $\vec{r}$ is the vector from the Sun
# to the Earth and $r$ is its magnitude $r = |\vec{r}|$.

# %%
def diffeq(y):
    [xpos, xvel, zpos, zvel] = y # first we unpack the vector y
    r = # magnitude of Earth-Sun distance
    xacc = 
    zacc = 
    ydot = np.array([xvel, xacc, zvel, zacc])
    return ydot


def move_RK2(diffeq, y, dt):
    ydot = diffeq( y )
    y_half = y + 1/2 * ydot * dt
    
    ydot_half  =  diffeq( y_half)
    y = y + ydot_half * dt
    
    return y
    

def move_Euler(diffeq, y, dt):
    ydot = diffeq( y )
    y = y+ ydot * dt
    return y

# %% [markdown]
# ## Task 4
#
# Simulate the Earth's trajectory for one year using the Runge-Kutta 2nd order method. The resulting
# trajectory should be a closed orbit that passes through both the Perihelion and Aphelion.

# %%
# Explain how you choose dt here
dt=
t_total = # task 4 (one year) and task 6 (two hundred years). Make sure it's in the right units
t_range = np.arange(0, t_total, dt)

# xpos xvel zpos zvel
y0 = [ , , , ] 
y = y0
x_sol = []
z_sol = []
EKin = []
EPot = []
Etot = []

for t in t_range:

# %% [markdown]
# ## Task 5
#
# Create a second plot to show the values of the energies (potential, kinetic, total) as a function of
# time. You can choose to plot this as a second subplot or in a separate figure.

# %%
#plotting section
fig, ax = plt.subplots(1)
ax.plot(0,0,'ro')
ax.text(0,0, 'Sun', horizontalalignment='left', verticalalignment='bottom', color='red')

ax.plot(-R1, 0,'k.')
ax.text(-R1, 0, 'Perihelion', horizontalalignment='left', verticalalignment='bottom')

ax.plot( R2, 0,'k.')
ax.text( R2, 0, 'Aphelion', horizontalalignment='right', verticalalignment='bottom')

ax.plot( ,  ,'b-') 

ax.set_ylabel('y position')
ax.set_xlabel('x position')
ax.set_aspect('equal', 'box')

plt.show()

# %% [markdown]
# ## Task 6
#
# Try to tweak Newton's law of gravitation a little bit by changing the exponent of $r$ in
# $-\frac{GMm}{r^3}\vec{r}$ from $-3$ to $-3.02$. Simulate the Earth's trajectory for 200 years.
# Describe what you see.

# %%
# Task 6: modify the exponent in diffeq() (or add a variant) and re-run the
# simulation with t_total set to 200 years. Describe your observations here.
